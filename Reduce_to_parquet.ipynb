# %% [markdown]
# # Reduce Data to parquet
#
# **Note: Run only once**
# - select a subset of columns
# - save in parquet format

# %%
import pandas as pd
import gc

# %%
# change the filepath as required, we have selected the folder with the latest date

## ------ California -------

filepath = '../data/VM2--CA--2022-04-25/'
DEMO_filename_in = 'VM2--CA--2022-04-25-DEMOGRAPHIC.tab'
VOTE_filename_in = 'VM2--CA--2022-04-25-VOTEHISTORY.tab'
DEMO_filename_out = 'VM2--CA--2022-04-25-DEMOGRAPHIC_selected_cols.parquet'
VOTE_filename_out = 'VM2--CA--2022-04-25-VOTEHISTORY_selected_cols.parquet'

## ------ Colorado -------

# filepath = '../data/VM2--CO--2022-04-26/'
# DEMO_filename_in = 'VM2--CO--2022-04-26-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--CO--2022-04-26-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--CO--2022-04-26-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--CO--2022-04-26-VOTEHISTORY_selected_cols.parquet'


# # ------ Maryland -------

# filepath = '../data/VM2--MD--2022-04-08/'
# DEMO_filename_in = 'VM2--MD--2022-04-08-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--MD--2022-04-08-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--MD--2022-04-08-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--MD--2022-04-08-VOTEHISTORY_selected_cols.parquet'


# # ------ Maine -------

# filepath = '../data/VM2--ME--2022-03-02/'
# DEMO_filename_in = 'VM2--ME--2022-03-02-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--ME--2022-03-02-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--ME--2022-03-02-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--ME--2022-03-02-VOTEHISTORY_selected_cols.parquet'


# # ------ Minnesota -------

# filepath = '../data/VM2--MN--2022-03-25/'
# DEMO_filename_in = 'VM2--MN--2022-03-25-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--MN--2022-03-25-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--MN--2022-03-25-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--MN--2022-03-25-VOTEHISTORY_selected_cols.parquet'


# # ------ New Mexico -------

# filepath = '../data/VM2--NM--2022-03-30/'
# DEMO_filename_in = 'VM2--NM--2022-03-30-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--NM--2022-03-30-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--NM--2022-03-30-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--NM--2022-03-30-VOTEHISTORY_selected_cols.parquet'


# # ------ Vermont -------

# filepath = '../data/VM2--VT--2022-04-20/'
# DEMO_filename_in = 'VM2--VT--2022-04-20-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--VT--2022-04-20-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--VT--2022-04-20-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--VT--2022-04-20-VOTEHISTORY_selected_cols.parquet'


# # ------ Utah -------

# filepath = '../data/VM2--UT--2022-03-30/'
# DEMO_filename_in = 'VM2--UT--2022-03-30-DEMOGRAPHIC.tab'
# VOTE_filename_in = 'VM2--UT--2022-03-30-VOTEHISTORY.tab'
# DEMO_filename_out = 'VM2--UT--2022-03-30-DEMOGRAPHIC_selected_cols.parquet'
# VOTE_filename_out = 'VM2--UT--2022-03-30-VOTEHISTORY_selected_cols.parquet'

# %% [markdown]
# # 1. Reduce DEMOGRAPHIC file to parquet
#
# **Note: Run only once**
# - select a subset of demography columns
# - save in parquet format

# %%
selected_variables = ['LALVOTERID',
                      'Residence_Addresses_City', 
                      'County',
                      'EthnicGroups_EthnicGroup1Desc',
                      'Voters_OfficialRegDate', 
                      'Voters_Age',
                      'Voters_Gender',        
                      'CommercialData_Education',
                      'CommercialData_EstimatedHHIncome',
                      'CommercialData_EstimatedHHIncomeAmount',
                      'FECDonors_NumberOfDonations',
                      'FECDonors_TotalDonationsAmount', 
                      'Parties_Description',
                      'Voters_BirthDate'
                     ]

state_demographic = pd.read_csv(f'{filepath}{DEMO_filename_in}', 
                                sep='\t', dtype=str, encoding='unicode_escape',
                                usecols=selected_variables)

state_demographic.head()
# Out:
#        LALVOTERID Residence_Addresses_City Voters_Gender Voters_Age  \
# 0  LALCA453164106                  Oakland             F         29
# 1  LALCA453008306                  Oakland             F         26
# 2   LALCA22129469                  Oakland             F         47
# 3  LALCA549803906                  Oakland             M         60
# 4   LALCA24729024              San Leandro             F         56
#
#   Voters_BirthDate Parties_Description EthnicGroups_EthnicGroup1Desc  \
# 0       04/29/1993          Democratic                         Other
# 1       02/02/1996        Non-Partisan       Likely African-American
# 2       02/02/1975          Democratic                      European
# 3       02/09/1962          Democratic                         Other
# 4       01/01/1966          Democratic                      European
#
#   Voters_OfficialRegDate   County       CommercialData_Education  \
# 0             06/18/2021  ALAMEDA                            NaN
# ...

# %%
state_demographic.to_parquet(f'{filepath}{DEMO_filename_out}')

# %%
del state_demographic
gc.collect()
# Out:
# 690

# %% [markdown]
# # 2. Reduce VOTEHISTORY file to parquet
#
# **Note: Run only once**
# 1. load the data with only one row to find out which dates are  "General" and "Local_Municipal"
# 2. create a list of columns that contains those dates
# 3. reload the data with only those columns and the voter ID (`LALVOTERID`) and all rows
# 4. save the data in parquet format

# %%
# 1. select only one rows to find the column names that are General and Local_or_Municipal elections
state_voterhistory_cols = pd.read_csv(f'{filepath}{VOTE_filename_in}',
                                 sep='\t', dtype=str, encoding='unicode_escape',
                                nrows=1)
                                
state_voterhistory_cols.head()
# Out:
#        LALVOTERID Special_2022_04_19 Special_2022_04_12 Special_2022_04_05  \
# 0  LALCA453164106                NaN                NaN                NaN
#
#   Special_2022_02_15 Special_2022_02_01 Special_2021_12_14 Special_2021_12_07  \
# 0                NaN                NaN                NaN                NaN
#
#   Special_2021_11_02 Consolidated_General_2021_11_02  ...  \
# 0                NaN                             NaN  ...
#
#   BallotReturnDate_General_2018_11_06 BallotReturnDate_Primary_2018_06_05  \
# 0                                 NaN                                 NaN
#
#   BallotReturnDate_General_2016_11_08 BallotReturnDate_Primary_2016_06_07  \
# 0                          11/07/2016                                 NaN
#
#   BallotReturnDate_General_2014_11_04 BallotReturnDate_Primary_2014_06_03  \
# 0                                 NaN                                 NaN
#
#   BallotReturnDate_General_2012_11_06 BallotReturnDate_Primary_2012_06_05  \
# ...

# %%
#2. select only voter ID and columns with General or Local_or_Municipal election dates

GE_cols = [col for col in state_voterhistory_cols.columns if col.startswith('General')]
print("total number of General election dates", len(GE_cols))

LM_cols = [col for col in state_voterhistory_cols.columns if col.startswith('Local_or_Municipal')]
print("total number of Local or Municipal election dates", len(LM_cols))

CG_cols = [col for col in state_voterhistory_cols.columns if col.startswith('Consolidated_General')]
print("total number of Consolidated General election dates", len(CG_cols))

needed_variables = ['LALVOTERID'] + LM_cols + GE_cols + CG_cols
# Out:
# total number of General election dates 18
# total number of Local or Municipal election dates 131
# total number of Consolidated General election dates 18

# %%
#3. reload the data with all columns related to General or Local_or_Municipal election dates and all rows 
state_voterhistory = pd.read_csv(f'{filepath}{VOTE_filename_in}',
                                 sep='\t', dtype=str, encoding='unicode_escape',
                                 usecols=needed_variables)
                                
state_voterhistory.head(5)
# Out:
#        LALVOTERID Consolidated_General_2021_11_02  \
# 0  LALCA453164106                             NaN
# 1  LALCA453008306                             NaN
# 2   LALCA22129469                             NaN
# 3  LALCA549803906                             NaN
# 4   LALCA24729024                             NaN
#
#   Local_or_Municipal_2021_08_31 Local_or_Municipal_2021_07_20  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   Local_or_Municipal_2021_06_08 Local_or_Municipal_2021_06_01  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# ...

# %%
#4. save to parquet format
state_voterhistory.to_parquet(f'{filepath}{VOTE_filename_out}')

# %%
del state_voterhistory
gc.collect()
# Out:
# 0
