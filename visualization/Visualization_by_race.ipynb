# %%
#!python3 -m pip install -U matplotlib
#!pip3 install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os

if not os.path.exists('../data/plots'):
    os.makedirs('../data/plots')

# %%
CA_get_rcv_nonrcv = pd.read_csv('../data/ca-cities.csv', usecols = ['RCV', 'city_ascii', 'state_id'])
All_rcv_nonrcv = pd.read_csv('../data/cities.csv', usecols = ['RCV', 'city_ascii', 'state_id'])
All_rcv_nonrcv = pd.concat([All_rcv_nonrcv, CA_get_rcv_nonrcv])
All_rcv_nonrcv.head()
# Out:
#    RCV    city_ascii state_id
# 0  NaN    Los Alamos       NM
# 1  NaN   Albuquerque       NM
# 2  NaN    Rio Rancho       NM
# 3  NaN    Farmington       NM
# 4  NaN  North Valley       NM

# %%
All_rcv_nonrcv = All_rcv_nonrcv.rename(columns ={"city_ascii": "Residence_Addresses_City", "state_id":"state"})
All_rcv_nonrcv['RCV'] = All_rcv_nonrcv['RCV'].fillna(0) 
All_rcv_nonrcv = All_rcv_nonrcv.drop_duplicates()
print(All_rcv_nonrcv.shape)
print("No. unique cities:", All_rcv_nonrcv.Residence_Addresses_City.nunique())
All_rcv_nonrcv.head()
# Out:
# (913, 3)
# No. unique cities: 889
#    RCV Residence_Addresses_City state
# 0  0.0               Los Alamos    NM
# 1  0.0              Albuquerque    NM
# 2  0.0               Rio Rancho    NM
# 3  0.0               Farmington    NM
# 4  0.0             North Valley    NM

# %%
cnt_multiple = All_rcv_nonrcv.groupby(['Residence_Addresses_City', 'state']).size().reset_index()
cnt_multiple.columns = ['Residence_Addresses_City', 'state', 'count']
cnt_multiple[cnt_multiple['count'] > 1]
# Out:
# Empty DataFrame
# Columns: [Residence_Addresses_City, state, count]
# Index: []

# %%
filepath = '../data/'
    
voter_turnout_merge = pd.read_csv(f'{filepath}voter_turnout_merged_all_states.csv')
print(voter_turnout_merge.shape)
print("No. unique cities in merged file:", voter_turnout_merge.Residence_Addresses_City.nunique())

voter_turnout_merge = voter_turnout_merge.merge(All_rcv_nonrcv, on = ["Residence_Addresses_City", "state"], how = "inner")
print(voter_turnout_merge.shape)
print("No. unique cities in merged file:", voter_turnout_merge.Residence_Addresses_City.nunique())
voter_turnout_merge = voter_turnout_merge.replace({"Local_or_Municipal": "Local or Municipal", 
                                        "Consolidated_General":"Consolidated General"})

voter_turnout_merge.tail()
# Out:
# (1492, 69)
# No. unique cities in merged file: 213
# (1492, 70)
# No. unique cities in merged file: 213
#      Residence_Addresses_City   elec_date  elec_year           elec_type  \
# 1487              Brattleboro  2014_11_04       2014             General
# 1488              Brattleboro  2022_03_01       2022  Local or Municipal
# 1489              Brattleboro  2021_03_02       2021  Local or Municipal
# 1490              Brattleboro  2020_06_30       2020  Local or Municipal
# 1491              Brattleboro  2019_03_05       2019  Local or Municipal
#
#       total_voters_asian  total_voters_black  total_voters_hispanic  \
# 1487               146.0                27.0                  234.0
# 1488               146.0                27.0                  234.0
# 1489               146.0                27.0                  234.0
# 1490               146.0                27.0                  234.0
# 1491               146.0                27.0                  234.0
#
#       total_voters_others  total_voters_white  voted_voters_asian  ...  \
# 1487                142.0              7255.0                20.0  ...
# 1488                142.0              7255.0                12.0  ...
# 1489                142.0              7255.0                12.0  ...
# 1490                142.0              7255.0                 5.0  ...
# 1491                142.0              7255.0                13.0  ...
#
#       total_voters_no_college  voted_voters_college  voted_voters_no_college  \
# 1487                   1283.0                1202.0                    467.0
# 1488                   1283.0                 640.0                    232.0
# 1489                   1283.0                 979.0                    307.0
# 1490                   1283.0                 308.0                    107.0
# 1491                   1283.0                 705.0                    256.0
#
#       perc_turnout_college  perc_turnout_no_college   mean_age  \
# 1487             40.349110                36.399065  58.330694
# 1488             21.483719                18.082619  62.480240
# 1489             32.863377                23.928293  58.890635
# 1490             10.339040                 8.339829  54.350145
# 1491             23.665660                19.953235  60.060868
#
#       voter_population  voted_voters  state  RCV
# 1487              9235        2318.0     VT  0.0
# 1488              9235        1245.0     VT  0.0
# 1489              9235        1895.0     VT  0.0
# 1490              9235         583.0     VT  0.0
# 1491              9235        1367.0     VT  0.0
#
# [5 rows x 70 columns]

# %%
# perc_turnout_asian and other races are calculated per election date, election type and city level
# we want to aggregate at election type level and city level, so remove the those columns

def select_cols(df):
    select_df = df[[col for col in df.columns\
                    if "RCV" in col or\
                    "elec_type" in col or\
                    "voters_asian" in col or\
                    "voters_black" in col or\
                    "voters_hispanic" in col or\
                    "voters_white" in col or\
                    "voters_others" in col or\
                    "perc_turnout_asian"  in col or\
                    "perc_turnout_black"  in col or\
                    "perc_turnout_hispanic"  in col or\
                    "perc_turnout_white"  in col or\
                    "perc_turnout_others"  in col 
                   ]]
    return select_df

# %% [markdown]
# ### Average turnout for white, black, Hispanic, and Asian voters in local, consolidated, and general elections
# -    Grouped bar graph by election type

# %%
def get_elec_turnout_race(df, RCV_nonRCV = False):
    if RCV_nonRCV == False:
        agg_df = df[[col for col in df.columns \
                        if "elec_type" in col or\
                        "perc_turnout_asian"  in col or\
                        "perc_turnout_black"  in col or\
                        "perc_turnout_hispanic"  in col or\
                        "perc_turnout_white"  in col or\
                        "perc_turnout_others"  in col ]]
        agg_df = agg_df.groupby('elec_type').mean().reset_index()
    if RCV_nonRCV == True:
        agg_df = df[[col for col in df.columns \
                        if "RCV" in col or\
                        "elec_type" in col or\
                        "perc_turnout_asian"  in col or\
                        "perc_turnout_black"  in col or\
                        "perc_turnout_hispanic"  in col or\
                        "perc_turnout_white"  in col or\
                        "perc_turnout_others"  in col ]]
        agg_df = agg_df.groupby(['elec_type', 'RCV']).mean().reset_index()
    return agg_df

# %%
voter_turnout_merge_race_ca = select_cols(voter_turnout_merge[voter_turnout_merge['state'] == 'CA'])
voter_turnout_merge_race_ca[voter_turnout_merge_race_ca['elec_type']=='Local or Municipal']
# Out:
#               elec_type  total_voters_asian  total_voters_black  \
# 64   Local or Municipal              3388.0                41.0
# 66   Local or Municipal              3388.0                41.0
# 72   Local or Municipal              4107.0               465.0
# 73   Local or Municipal              4107.0               465.0
# 74   Local or Municipal              4107.0               465.0
# 75   Local or Municipal              4107.0               465.0
# 93   Local or Municipal               679.0                29.0
# 145  Local or Municipal              8883.0              4945.0
# 147  Local or Municipal              8883.0              4945.0
#
#      total_voters_hispanic  total_voters_others  total_voters_white  \
# 64                 23123.0               1637.0              2970.0
# 66                 23123.0               1637.0              2970.0
# 72                 15564.0              11056.0             32766.0
# 73                 15564.0              11056.0             32766.0
# 74                 15564.0              11056.0             32766.0
# 75                 15564.0              11056.0             32766.0
# 93                 30868.0                433.0              3193.0
# 145                78806.0               5410.0             77680.0
# 147                78806.0               5410.0             77680.0
#
#      voted_voters_asian  voted_voters_black  voted_voters_hispanic  \
# 64                431.0                 1.0                 2187.0
# 66                389.0                 1.0                 1716.0
# 72                375.0                18.0                 1171.0
# 73                439.0                39.0                 1190.0
# 74                391.0                17.0                 1109.0
# 75                389.0                16.0                 1172.0
# 93                 48.0                 3.0                 1913.0
# 145               682.0               518.0                 3310.0
# 147               438.0               245.0                 3875.0
#
#      voted_voters_others  voted_voters_white  perc_turnout_asian  \
# 64                 262.0               432.0           12.721370
# 66                 113.0               344.0           11.481700
# 72                 822.0              5377.0            9.130752
# 73                 585.0              5147.0           10.689067
# 74                 702.0              5027.0            9.520331
# 75                1143.0              4914.0            9.471634
# 93                  39.0               305.0            7.069219
# 145                349.0              7202.0            7.677586
# 147                294.0              9288.0            4.930767
#
#      perc_turnout_black  perc_turnout_hispanic  perc_turnout_others  \
# 64             2.439024               9.458115            16.004887
# 66             2.439024               7.421182             6.902871
# 72             3.870968               7.523773             7.434877
# 73             8.387097               7.645849             5.291245
# 74             3.655914               7.125418             6.349493
# 75             3.440860               7.530198            10.338278
# 93            10.344828               6.197356             9.006928
# 145           10.475228               4.200188             6.451017
# 147            4.954499               4.917138             5.434381
#
#      perc_turnout_white  RCV
# 64            14.545455  0.0
# 66            11.582492  0.0
# 72            16.410303  0.0
# 73            15.708356  0.0
# 74            15.342123  0.0
# 75            14.997253  0.0
# 93             9.552145  0.0
# 145            9.271370  0.0
# 147           11.956746  0.0

# %%
## Overall 
voter_turnout_merge_race_all = select_cols(voter_turnout_merge)
elec_turnout_per_race_all = get_elec_turnout_race(voter_turnout_merge_race_all, RCV_nonRCV = False) 
elec_turnout_per_race_all.columns = [col.replace('perc_turnout_', '') for col in elec_turnout_per_race_all.columns]

fig = elec_turnout_per_race_all.plot(x='elec_type',
                             kind='bar',
                             stacked=False,
                             title=f'Pooled voter turnout per race',
                             figsize=(8, 5), 
                             rot=0, ylabel = "percentage of voter turnout").legend(["asian", "black", "hispanic", "others", "white"]).get_figure()

fig.savefig('../data/plots/pooled_elec_turnout_per_race.jpg')

# %%
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(15, 20), sharey='row', sharex='all')
plt.subplots_adjust(hspace=0.5)
fig.suptitle('Voter turnout per race and state', fontsize=15, y=0.95)

for s, ax in zip(sorted(voter_turnout_merge.state.unique(), reverse =True), axs.ravel()):
    if s=='CA':
        filepath = '../data/VM2--CA--2022-04-25'  
    if s=='CO':
        filepath = '../data/VM2--CO--2022-04-26/'
    if s=='MD':
        filepath = '../data/VM2--MD--2022-04-08/'
    if s=='ME':
        filepath = '../data/VM2--ME--2022-03-02/'
    if s=='MN':
        filepath = '../data/VM2--MN--2022-03-25/'
    if s=='NM':
        filepath = '../data/VM2--NM--2022-03-30/'
    if s=='UT':
        filepath = '../data/VM2--UT--2022-03-30/'
    if s=='VT':
        filepath = '../data/VM2--VT--2022-04-20/'
        
    voter_turnout_merge_race = select_cols(voter_turnout_merge[voter_turnout_merge['state'] == s])
    elec_turnout_per_race = get_elec_turnout_race(voter_turnout_merge_race, RCV_nonRCV = False) 
    elec_turnout_per_race.columns = [col.replace('perc_turnout_', '') for col in elec_turnout_per_race.columns]
    elec_turnout_per_race = elec_turnout_per_race.replace({"Local or Municipal": "Local or\nMunicipal", 
                                        "Consolidated General":"Consolidated\nGeneral"})

    fig = elec_turnout_per_race.plot(x='elec_type',
                                     kind='bar',
                                     title=f'{s}\'s voter turnout per race',
                                     figsize=(18, 8), 
                                     rot=0,  
                                     ax=ax).legend(["asian", "black", "hispanic", "others", "white"]).get_figure()
    
    ax.set_title(s)
    if s == 'VT':
        ax.set_ylabel("percentage")
    elif s == 'ME':
        ax.set_ylabel("percentage")
        ax.set_xlabel("election type")
        ax.get_legend().remove()
    
    else:
        ax.get_legend().remove()
    ax.set_xlabel("election type")
    ax.tick_params(axis='x', labelrotation = 0)
  
ax.figure.savefig(f'../data/plots/elec_turnout_per_race.jpg')

# %%
elec_turnout_per_race_both_all =get_elec_turnout_race(voter_turnout_merge_race_all, RCV_nonRCV = True) 
elec_turnout_per_race_both_all = elec_turnout_per_race_both_all.pivot(index = 'elec_type', columns = 'RCV')
elec_turnout_per_race_both_all = round(elec_turnout_per_race_both_all)
elec_turnout_per_race_both_all.index = elec_turnout_per_race_both_all.index.str.replace('Local or Municipal', 'Local or\nMunicipal')
elec_turnout_per_race_both_all.index = elec_turnout_per_race_both_all.index.str.replace('Consolidated General', 'Consolidated\nGeneral')

fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(18, 4), sharey='row')#, sharex='col')
plt.subplots_adjust(hspace=0.1)
fig_suptitle = fig.suptitle(f'Pooled voter turnout per race \n (RCV vs non-RCV)', fontsize=15, y=1.1)

races = ['perc_turnout_asian', 'perc_turnout_black', 'perc_turnout_hispanic',
          'perc_turnout_others', 'perc_turnout_white']

# loop through tickers and axes
for race, ax in zip(races, axs.ravel()):
    fig = elec_turnout_per_race_both_all[[race]].plot.bar(ax=ax)
    ax.set_title(race.replace('perc_turnout_', ''))
    if race == 'perc_turnout_asian':
        ax.set_ylabel("percentage")
        ax.legend(labels=["Non RCV", "RCV"])
    else:
        ax.get_legend().remove()
    ax.set_xlabel("election type")
    ax.set_ylim(0, 80)
    ax.tick_params(axis='x', labelrotation = 0)

ax.figure.savefig('../data/plots/pooled_elec_turnout_per_race_sep.jpg', bbox_inches='tight', bbox_extra_artists=[fig_suptitle])

# %%
for s in sorted(voter_turnout_merge.state.unique(), reverse =True):
    if s=='CA':
        filepath = '../data/VM2--CA--2022-04-25'  
    if s=='CO':
        filepath = '../data/VM2--CO--2022-04-26/'
    if s=='MD':
        filepath = '../data/VM2--MD--2022-04-08/'
    if s=='ME':
        filepath = '../data/VM2--ME--2022-03-02/'
    if s=='MN':
        filepath = '../data/VM2--MN--2022-03-25/'
    if s=='NM':
        filepath = '../data/VM2--NM--2022-03-30/'
    if s=='UT':
        filepath = '../data/VM2--UT--2022-03-30/'
    if s=='VT':
        filepath = '../data/VM2--VT--2022-04-20/'
        
    voter_turnout_merge_race = select_cols(voter_turnout_merge[voter_turnout_merge['state'] == s])
    elec_turnout_per_race_both =get_elec_turnout_race(voter_turnout_merge_race, RCV_nonRCV = True) 
    elec_turnout_per_race_both = elec_turnout_per_race_both.pivot(index = 'elec_type', columns = 'RCV')
    elec_turnout_per_race_both = round(elec_turnout_per_race_both)
    elec_turnout_per_race_both.index = elec_turnout_per_race_both.index.str.replace('Local or Municipal', 'Local or\nMunicipal')
    elec_turnout_per_race_both.index = elec_turnout_per_race_both.index.str.replace('Consolidated General', 'Consolidated\nGeneral')

    races = ['perc_turnout_asian', 'perc_turnout_black', 'perc_turnout_hispanic',
              'perc_turnout_others', 'perc_turnout_white']

    fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(18, 4), sharey='row', sharex='all')#, sharex='col')
    plt.subplots_adjust(hspace=0.5)
    fig_suptitle = fig.suptitle(f'{s}\'s voter turnout per race \n (RCV vs non-RCV)', fontsize=15, y=1.1)

    # loop through tickers and axes
    for race, ax in zip(races, axs.ravel()):
        fig = elec_turnout_per_race_both[[race]].plot(kind='bar', ax=ax)
        ax.set_title(race.replace('perc_turnout_', ''))
        if race == 'perc_turnout_asian':
            ax.set_ylabel("percentage")
            ax.legend(labels=["Non RCV", "RCV"])
        else:
            ax.get_legend().remove()
        ax.set_xlabel("election type")
        ax.set_ylim(0, 80)
        ax.tick_params(axis='x', labelrotation = 0)

    fig.figure.savefig(f'../data/plots/elec_turnout_per_race_sep_{s}.jpg', bbox_inches='tight', bbox_extra_artists=[fig_suptitle])

# %% [markdown]
# ### Average gap in turnout between white and non-white voters in local, consolidated, and general elections
# -    Bar graph by election type

# %%
# sum up total_voters and voted_voters for all races except for white

def add_non_white(df):

    non_white_cols = [col for col in df if "elec_type" not in col and "voters_white" not in col]
    for v in ['total_voters_', 'voted_voters_']:
        df.loc[:,v+'non_white'] = df[[col for col in non_white_cols if v in col ]].sum(axis =1)

    df.loc[:,'perc_turnout_non_white'] =  df.loc[:,'voted_voters_non_white']/df.loc[:,'total_voters_non_white']*100

    ## find the gap of voter's turnout for each record (city, election type and election date levels)
    df.loc[:,'gap_white_non_white'] = df.loc[:,'perc_turnout_white']  - df.loc[:,'perc_turnout_non_white']  

    return df

# %%
 voter_turnout_merge.state.unique()
# Out:
# array(['CA', 'CO', 'MD', 'ME', 'MN', 'NM', 'UT', 'VT'], dtype=object)

# %%
voter_turnout_merge_race_all = select_cols(voter_turnout_merge)
voter_turnout_merge_race_all = add_non_white(voter_turnout_merge_race_all)

## take the average per election type
elec_turnout_per_whiteOrNot_all = voter_turnout_merge_race_all[['elec_type', 'gap_white_non_white']].groupby('elec_type').mean().reset_index()
elec_turnout_per_whiteOrNot_all = elec_turnout_per_whiteOrNot_all.replace({"Local or Municipal": "LocalMunicipal", 
                                                                "Consolidated_General":"Consolidated"})
fig = elec_turnout_per_whiteOrNot_all.plot(x='elec_type',
                                 kind='bar',
                                 stacked=False,
                                 title=f'Pooled average gap between white and non white voter',
                                 figsize=(8, 5), 
                                 rot=0, ylabel = "percentage gap", xlabel ="election type",
                                          legend=False).get_figure()
fig.savefig(f'../data/plots/pooled_elec_turnout_per_whiteOrNot.jpg')
# Out:
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,v+'non_white'] = df[[col for col in non_white_cols if v in col ]].sum(axis =1)
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,v+'non_white'] = df[[col for col in non_white_cols if v in col ]].sum(axis =1)
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'perc_turnout_non_white'] =  df.loc[:,'voted_voters_non_white']/df.loc[:,'total_voters_non_white']*100
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'gap_white_non_white'] = df.loc[:,'perc_turnout_white']  - df.loc[:,'perc_turnout_non_white']

# %%
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(18, 8), sharey='row', sharex='all')#, sharex='col')
plt.subplots_adjust(hspace=0.5)
fig.suptitle('Average gap in turnout between white and non-white voters', fontsize=15, y=0.95)

for s, ax in zip(sorted(voter_turnout_merge.state.unique(), reverse =True), axs.ravel()):
    if s=='CA':
        filepath = '../data/VM2--CA--2022-04-25'  
    if s=='CO':
        filepath = '../data/VM2--CO--2022-04-26/'
    if s=='MD':
        filepath = '../data/VM2--MD--2022-04-08/'
    if s=='ME':
        filepath = '../data/VM2--ME--2022-03-02/'
    if s=='MN':
        filepath = '../data/VM2--MN--2022-03-25/'
    if s=='NM':
        filepath = '../data/VM2--NM--2022-03-30/'
    if s=='UT':
        filepath = '../data/VM2--UT--2022-03-30/'
    if s=='VT':
        filepath = '../data/VM2--VT--2022-04-20/'
        
    
    voter_turnout_merge_race = select_cols(voter_turnout_merge[voter_turnout_merge['state'] == s])
    voter_turnout_merge_race = add_non_white(voter_turnout_merge_race)

    ## take the average per election type
    elec_turnout_per_whiteOrNot = voter_turnout_merge_race[['elec_type', 'gap_white_non_white']].groupby('elec_type').mean().reset_index()
    elec_turnout_per_whiteOrNot = elec_turnout_per_whiteOrNot.replace({"Local or Municipal": "Local or\nMunicipal", 
                                                                    "Consolidated General":"Consolidated\nGeneral"})
    fig = elec_turnout_per_whiteOrNot.plot(x = 'elec_type', subplots=True, kind = 'bar', ax=ax)
    ax.set_title(s)
    if s == 'CA':
        ax.set_ylabel("percentage")
        ax.get_legend().remove()
    else:
        ax.get_legend().remove()
    ax.set_xlabel("election type")
    ax.set_ylim(0, 20)
    ax.tick_params(axis='x', labelrotation = 0)
  
ax.figure.savefig(f'../data/plots/elec_turnout_per_whiteOrNot.jpg')

# %%
voter_turnout_merge_race_all = select_cols(voter_turnout_merge)
voter_turnout_merge_race_all = add_non_white(voter_turnout_merge_race_all)

elec_turnout_per_whiteOrNot_both_all = voter_turnout_merge_race_all[['elec_type', 'gap_white_non_white','RCV']].groupby(['RCV', 'elec_type']).mean().reset_index()
elec_turnout_per_whiteOrNot_both_all = elec_turnout_per_whiteOrNot_both_all.replace({"Local or Municipal": "LocalMunicipal", 
                                                                "Consolidated_General":"Consolidated"})
elec_turnout_per_whiteOrNot_both_all = elec_turnout_per_whiteOrNot_both_all.pivot_table(index = 'elec_type', columns = 'RCV')

fig = elec_turnout_per_whiteOrNot_both_all.plot.bar(xlabel="election type", ylabel = "percentage", 
                                                    figsize=(8, 5),rot=0,
                                                   title = 'Pooled average gap in turnout between white and non-white voters \n (RCV vs non-RCV))').legend(labels=["Non RCV", "RCV"]).get_figure()


fig.savefig(f'../data/plots/pooled_elec_turnout_per_whiteOrNot_sep.jpg')
# Out:
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,v+'non_white'] = df[[col for col in non_white_cols if v in col ]].sum(axis =1)
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,v+'non_white'] = df[[col for col in non_white_cols if v in col ]].sum(axis =1)
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'perc_turnout_non_white'] =  df.loc[:,'voted_voters_non_white']/df.loc[:,'total_voters_non_white']*100
# /var/folders/ww/21cvzb4164325blmx95x6cd80000gp/T/ipykernel_10491/3148758691.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'gap_white_non_white'] = df.loc[:,'perc_turnout_white']  - df.loc[:,'perc_turnout_non_white']

# %%
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(18, 8), sharey='row', sharex='all')
plt.subplots_adjust(hspace=0.5)
fig.suptitle('Average gap in turnout between white and non-white voters\n (RCV VS. non-RCV)', fontsize=15, y=0.95)

for s, ax in zip(sorted(voter_turnout_merge.state.unique(), reverse =True), axs.ravel()):
    if s=='CA':
        filepath = '../data/VM2--CA--2022-04-25'  
    if s=='CO':
        filepath = '../data/VM2--CO--2022-04-26/'
    if s=='MD':
        filepath = '../data/VM2--MD--2022-04-08/'
    if s=='ME':
        filepath = '../data/VM2--ME--2022-03-02/'
    if s=='MN':
        filepath = '../data/VM2--MN--2022-03-25/'
    if s=='NM':
        filepath = '../data/VM2--NM--2022-03-30/'
    if s=='UT':
        filepath = '../data/VM2--UT--2022-03-30/'
    if s=='VT':
        filepath = '../data/VM2--VT--2022-04-20/'        
    
    voter_turnout_merge_race = select_cols(voter_turnout_merge[voter_turnout_merge['state'] == s])
    voter_turnout_merge_race = add_non_white(voter_turnout_merge_race)

    elec_turnout_per_whiteOrNot_both = voter_turnout_merge_race[['elec_type', 'gap_white_non_white','RCV']].groupby(['RCV', 'elec_type']).mean().reset_index()
    elec_turnout_per_whiteOrNot_both = elec_turnout_per_whiteOrNot_both.replace({"Local or Municipal": "Local or \nMunicipal", 
                                                                    "Consolidated General":"Consolidated \nGeneral"})
    elec_turnout_per_whiteOrNot_both = elec_turnout_per_whiteOrNot_both.pivot_table(index = 'elec_type', columns = 'RCV')
    fig = elec_turnout_per_whiteOrNot_both.plot.bar(ax=ax)

    ax.set_title(s)
    if s == 'VT':
        ax.set_ylabel("percentage")
        ax.legend(labels=["Non RCV", "RCV"])
    elif s == 'ME':
        ax.set_ylabel("percentage")
        ax.get_legend().remove()
    else:
        ax.get_legend().remove()
    ax.set_xlabel("election type")
    ax.set_ylim(0, 20)
    ax.tick_params(axis='x', labelrotation = 0)

ax.figure.savefig(f'../data/plots/elec_turnout_per_whiteOrNot_sep.jpg')
